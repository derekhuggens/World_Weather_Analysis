# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Import the requests library.
import requests, json

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waingapu
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | klaksvik
# Processing Record 13 of Set 1 | bakchar
# Processing Record 14 of Set 1 | yasnyy
# Processing Record 15 of Set 1 | jega
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | brigantine
# Processing Record 19 of Set 1 | orapa
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | mount gambier
# Processing Record 22 of Set 1 | lasa
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | torit
# Processing Record 25 of Set 1 | uarini
# Processing Record 26 of Set 1 | trinidad
# Processing Record 27 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | bermeo
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | gladstone
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | husavik
# Processing Record 38 of Set 1 | lahaina
# Processing Record 39 of Set 1 | talkha
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | havoysund
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | batemans bay
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | melfi
# Processing Record 1 of Set 2 | hailun
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | tambun
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | airai
# Processing Record 6 of Set 2 | port keats
# Processing Record 7 of Set 2 | vanimo
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | chajul
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | general pico
# Processing Record 12 of Set 2 | mweka
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | irtyshskiy
# Processing Record 15 of Set 2 | kavaratti
# Processing Record 16 of Set 2 | tomatlan
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | coahuayana
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | college
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | progreso
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | nabire
# Processing Record 29 of Set 2 | gold coast
# Processing Record 30 of Set 2 | vostok
# Processing Record 31 of Set 2 | bintulu
# Processing Record 32 of Set 2 | awjilah
# Processing Record 33 of Set 2 | na klang
# Processing Record 34 of Set 2 | novosokolniki
# Processing Record 35 of Set 2 | lamar
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | beisfjord
# Processing Record 38 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | grand gaube
# Processing Record 41 of Set 2 | almaznyy
# Processing Record 42 of Set 2 | vilyuysk
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | beloha
# Processing Record 46 of Set 2 | shimoda
# Processing Record 47 of Set 2 | oranjemund
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | margasari
# Processing Record 50 of Set 2 | lima
# Processing Record 1 of Set 3 | urumqi
# Processing Record 2 of Set 3 | krasnousolskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | coro
# Processing Record 4 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 3 | abeche
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | omsukchan
# Processing Record 11 of Set 3 | mastung
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | piskivka
# Processing Record 15 of Set 3 | anchorage
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | la vega
# Processing Record 18 of Set 3 | mchinji
# Processing Record 19 of Set 3 | kovdor
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | crotone
# Processing Record 22 of Set 3 | klyavlino
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | znamenskoye
# Processing Record 25 of Set 3 | biharamulo
# Processing Record 26 of Set 3 | praia
# Processing Record 27 of Set 3 | berlevag
# Processing Record 28 of Set 3 | meulaboh
# Processing Record 29 of Set 3 | alice springs
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | henties bay
# Processing Record 32 of Set 3 | filadelfia
# Processing Record 33 of Set 3 | dvorichna
# Processing Record 34 of Set 3 | hofn
# Processing Record 35 of Set 3 | goderich
# Processing Record 36 of Set 3 | mankono
# Processing Record 37 of Set 3 | strezhevoy
# Processing Record 38 of Set 3 | nieuw nickerie
# Processing Record 39 of Set 3 | chapais
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | biala podlaska
# Processing Record 42 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 3 | acaponeta
# Processing Record 44 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 3 | chaoyang
# Processing Record 46 of Set 3 | kintampo
# Processing Record 47 of Set 3 | gamba
# Processing Record 48 of Set 3 | kununurra
# Processing Record 49 of Set 3 | pangkalanbuun
# Processing Record 50 of Set 3 | hilo
# Processing Record 1 of Set 4 | north bend
# Processing Record 2 of Set 4 | nanortalik
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | puerto colombia
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | roebourne
# Processing Record 8 of Set 4 | nishihara
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | porto santo
# Processing Record 11 of Set 4 | mangan
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | umm lajj
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | mozarlandia
# Processing Record 16 of Set 4 | aktau
# Processing Record 17 of Set 4 | biskamzha
# Processing Record 18 of Set 4 | vila
# Processing Record 19 of Set 4 | manassas
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | bara
# Processing Record 22 of Set 4 | iwanai
# Processing Record 23 of Set 4 | gelemso
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | mayo
# Processing Record 26 of Set 4 | ballina
# Processing Record 27 of Set 4 | jvari
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | visnes
# Processing Record 30 of Set 4 | binzhou
# Processing Record 31 of Set 4 | marinette
# Processing Record 32 of Set 4 | great yarmouth
# Processing Record 33 of Set 4 | lubbock
# Processing Record 34 of Set 4 | lloydminster
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | songjianghe
# Processing Record 38 of Set 4 | kibala
# Processing Record 39 of Set 4 | santa cruz
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | thinadhoo
# Processing Record 42 of Set 4 | krasnokamensk
# Processing Record 43 of Set 4 | faanui
# Processing Record 44 of Set 4 | new norfolk
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | comodoro rivadavia
# Processing Record 47 of Set 4 | zabol
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | trairi
# Processing Record 1 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 5 | lucapa
# Processing Record 3 of Set 5 | ucluelet
# Processing Record 4 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 5 | flin flon
# Processing Record 6 of Set 5 | lukavica
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | iberia
# Processing Record 9 of Set 5 | pampierstad
# Processing Record 10 of Set 5 | alto longa
# Processing Record 11 of Set 5 | orodara
# Processing Record 12 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | wanning
# Processing Record 17 of Set 5 | sodhra
# Processing Record 18 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | oistins
# Processing Record 21 of Set 5 | terekli-mekteb
# Processing Record 22 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 23 of Set 5 | olinda
# Processing Record 24 of Set 5 | kandrian
# Processing Record 25 of Set 5 | daru
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | linkoping
# Processing Record 29 of Set 5 | athabasca
# Processing Record 30 of Set 5 | mizdah
# Processing Record 31 of Set 5 | krasnoselkup
# Processing Record 32 of Set 5 | pandan
# Processing Record 33 of Set 5 | genhe
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | rio grande
# Processing Record 36 of Set 5 | portland
# Processing Record 37 of Set 5 | cidreira
# Processing Record 38 of Set 5 | saint-joseph
# Processing Record 39 of Set 5 | hambantota
# Processing Record 40 of Set 5 | sabang
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | bathsheba
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | nongan
# Processing Record 45 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 5 | haines junction
# Processing Record 47 of Set 5 | rocha
# Processing Record 48 of Set 5 | monte alegre
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | honningsvag
# Processing Record 1 of Set 6 | san fernando
# Processing Record 2 of Set 6 | fort smith
# Processing Record 3 of Set 6 | yuncheng
# Processing Record 4 of Set 6 | hulyaypole
# Processing Record 5 of Set 6 | juneau
# Processing Record 6 of Set 6 | yangjiang
# Processing Record 7 of Set 6 | merauke
# Processing Record 8 of Set 6 | ranfurly
# Processing Record 9 of Set 6 | matamoros
# Processing Record 10 of Set 6 | lewistown
# Processing Record 11 of Set 6 | torbay
# Processing Record 12 of Set 6 | talen
# Processing Record 13 of Set 6 | prince rupert
# Processing Record 14 of Set 6 | peniche
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | nikolskoye
# Processing Record 17 of Set 6 | tabuk
# Processing Record 18 of Set 6 | jining
# Processing Record 19 of Set 6 | domoni
# Processing Record 20 of Set 6 | monroe
# Processing Record 21 of Set 6 | mlowo
# Processing Record 22 of Set 6 | dwarka
# Processing Record 23 of Set 6 | atar
# Processing Record 24 of Set 6 | srinagar
# Processing Record 25 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 6 | centralia
# Processing Record 27 of Set 6 | dorchester
# Processing Record 28 of Set 6 | taoudenni
# Processing Record 29 of Set 6 | okha
# Processing Record 30 of Set 6 | east london
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | arraial do cabo
# Processing Record 33 of Set 6 | biak
# Processing Record 34 of Set 6 | grand-lahou
# Processing Record 35 of Set 6 | saint-pierre
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | norsup
# Processing Record 38 of Set 6 | guatire
# Processing Record 39 of Set 6 | beringovskiy
# Processing Record 40 of Set 6 | zambezi
# Processing Record 41 of Set 6 | bilibino
# Processing Record 42 of Set 6 | morozovsk
# Processing Record 43 of Set 6 | spas-demensk
# Processing Record 44 of Set 6 | umm kaddadah
# Processing Record 45 of Set 6 | ivankiv
# Processing Record 46 of Set 6 | banjar
# Processing Record 47 of Set 6 | bowen
# Processing Record 48 of Set 6 | saint george
# Processing Record 49 of Set 6 | payakumbuh
# Processing Record 50 of Set 6 | santa rosa
# Processing Record 1 of Set 7 | shirokiy
# Processing Record 2 of Set 7 | santa cecilia
# Processing Record 3 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 7 | ponta do sol
# Processing Record 5 of Set 7 | tuatapere
# Processing Record 6 of Set 7 | coari
# Processing Record 7 of Set 7 | tulun
# Processing Record 8 of Set 7 | zhangjiakou
# Processing Record 9 of Set 7 | sorland
# Processing Record 10 of Set 7 | chaman
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | hualmay
# Processing Record 13 of Set 7 | puerto escondido
# Processing Record 14 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 7 | gilgit
# Processing Record 16 of Set 7 | havelock
# Processing Record 17 of Set 7 | sault sainte marie
# Processing Record 18 of Set 7 | idar
# Processing Record 19 of Set 7 | la ronge
# Processing Record 20 of Set 7 | yuli
# Processing Record 21 of Set 7 | mwense
# Processing Record 22 of Set 7 | humen
# Processing Record 23 of Set 7 | dunmore east
# Processing Record 24 of Set 7 | dondo
# Processing Record 25 of Set 7 | darhan
# Processing Record 26 of Set 7 | iqaluit
# Processing Record 27 of Set 7 | hasaki
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | sobolevo
# Processing Record 30 of Set 7 | burica
# City not found. Skipping...
# Processing Record 31 of Set 7 | edinburg
# Processing Record 32 of Set 7 | clyde river
# Processing Record 33 of Set 7 | liberal
# Processing Record 34 of Set 7 | sao jose da coroa grande
# Processing Record 35 of Set 7 | olafsvik
# Processing Record 36 of Set 7 | halifax
# Processing Record 37 of Set 7 | sola
# Processing Record 38 of Set 7 | mackay
# Processing Record 39 of Set 7 | dasoguz
# Processing Record 40 of Set 7 | kahului
# Processing Record 41 of Set 7 | makakilo city
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | teneguiban
# City not found. Skipping...
# Processing Record 44 of Set 7 | mitchell
# Processing Record 45 of Set 7 | callaway
# Processing Record 46 of Set 7 | khani
# Processing Record 47 of Set 7 | maneadero
# Processing Record 48 of Set 7 | gunjur
# Processing Record 49 of Set 7 | christchurch
# Processing Record 50 of Set 7 | rumphi
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | polyarnyy
# Processing Record 3 of Set 8 | royan
# Processing Record 4 of Set 8 | shingu
# Processing Record 5 of Set 8 | mocajuba
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | tawang
# Processing Record 8 of Set 8 | manzanillo
# Processing Record 9 of Set 8 | gollere
# City not found. Skipping...
# Processing Record 10 of Set 8 | camocim
# Processing Record 11 of Set 8 | dali
# Processing Record 12 of Set 8 | san jose
# Processing Record 13 of Set 8 | asyut
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | luzhou
# Processing Record 17 of Set 8 | hay river
# Processing Record 18 of Set 8 | lexington park
# Processing Record 19 of Set 8 | rabo de peixe
# Processing Record 20 of Set 8 | kupang
# Processing Record 21 of Set 8 | fussen
# Processing Record 22 of Set 8 | key west
# Processing Record 23 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 8 | avallon
# Processing Record 25 of Set 8 | high level
# Processing Record 26 of Set 8 | namtsy
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | brae
# Processing Record 29 of Set 8 | karratha
# Processing Record 30 of Set 8 | adamas
# Processing Record 31 of Set 8 | kysyl-syr
# Processing Record 32 of Set 8 | laguna
# Processing Record 33 of Set 8 | ossora
# Processing Record 34 of Set 8 | leningradskiy
# Processing Record 35 of Set 8 | sao joao da barra
# Processing Record 36 of Set 8 | muskogee
# Processing Record 37 of Set 8 | aloleng
# Processing Record 38 of Set 8 | abha
# Processing Record 39 of Set 8 | dakar
# Processing Record 40 of Set 8 | vestmannaeyjar
# Processing Record 41 of Set 8 | quatre cocos
# Processing Record 42 of Set 8 | myaundzha
# Processing Record 43 of Set 8 | jilikul
# Processing Record 44 of Set 8 | noumea
# Processing Record 45 of Set 8 | bonavista
# Processing Record 46 of Set 8 | avenal
# Processing Record 47 of Set 8 | ballitoville
# Processing Record 48 of Set 8 | san cristobal
# Processing Record 49 of Set 8 | sopetran
# Processing Record 50 of Set 8 | shubarshi
# Processing Record 1 of Set 9 | magadan
# Processing Record 2 of Set 9 | tacuarembo
# Processing Record 3 of Set 9 | port pirie
# Processing Record 4 of Set 9 | phulji
# Processing Record 5 of Set 9 | bratsk
# Processing Record 6 of Set 9 | tevriz
# Processing Record 7 of Set 9 | newala
# Processing Record 8 of Set 9 | kletskaya
# Processing Record 9 of Set 9 | lufkin
# Processing Record 10 of Set 9 | saskatoon
# Processing Record 11 of Set 9 | katobu
# Processing Record 12 of Set 9 | arrecife
# Processing Record 13 of Set 9 | miles city
# Processing Record 14 of Set 9 | talcahuano
# Processing Record 15 of Set 9 | ikalamavony
# Processing Record 16 of Set 9 | port lincoln
# Processing Record 17 of Set 9 | siva
# Processing Record 18 of Set 9 | gigmoto
# Processing Record 19 of Set 9 | tamandare
# Processing Record 20 of Set 9 | bitung
# Processing Record 21 of Set 9 | port-gentil
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | itarema
# Processing Record 24 of Set 9 | duz
# City not found. Skipping...
# Processing Record 25 of Set 9 | llanes
# Processing Record 26 of Set 9 | wetzlar
# Processing Record 27 of Set 9 | jalu
# Processing Record 28 of Set 9 | manzil salim
# Processing Record 29 of Set 9 | zaozerne
# Processing Record 30 of Set 9 | poum
# Processing Record 31 of Set 9 | pak chong
# Processing Record 32 of Set 9 | gorontalo
# Processing Record 33 of Set 9 | buala
# Processing Record 34 of Set 9 | killybegs
# Processing Record 35 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 36 of Set 9 | curvelo
# Processing Record 37 of Set 9 | gao
# Processing Record 38 of Set 9 | teahupoo
# Processing Record 39 of Set 9 | boyolangu
# Processing Record 40 of Set 9 | cukai
# Processing Record 41 of Set 9 | galway
# Processing Record 42 of Set 9 | antalaha
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | brindisi
# Processing Record 45 of Set 9 | along
# Processing Record 46 of Set 9 | bullhead city
# Processing Record 47 of Set 9 | kapit
# Processing Record 48 of Set 9 | camalu
# Processing Record 49 of Set 9 | hollola
# Processing Record 50 of Set 9 | sitio novo do tocantins
# Processing Record 1 of Set 10 | ukiah
# Processing Record 2 of Set 10 | novikovo
# Processing Record 3 of Set 10 | hamilton
# Processing Record 4 of Set 10 | omboue
# Processing Record 5 of Set 10 | lagoa
# Processing Record 6 of Set 10 | bandarbeyla
# Processing Record 7 of Set 10 | wana
# Processing Record 8 of Set 10 | rozivka
# Processing Record 9 of Set 10 | fortuna
# Processing Record 10 of Set 10 | careiro da varzea
# Processing Record 11 of Set 10 | nadym
# Processing Record 12 of Set 10 | ternate
# Processing Record 13 of Set 10 | carutapera
# Processing Record 14 of Set 10 | lazaro cardenas
# Processing Record 15 of Set 10 | severo-kurilsk
# Processing Record 16 of Set 10 | hobyo
# Processing Record 17 of Set 10 | marzuq
# Processing Record 18 of Set 10 | samara
# Processing Record 19 of Set 10 | lavrentiya
# Processing Record 20 of Set 10 | antsirabe
# Processing Record 21 of Set 10 | longonjo
# Processing Record 22 of Set 10 | rawdon
# Processing Record 23 of Set 10 | hirado
# Processing Record 24 of Set 10 | pitimbu
# Processing Record 25 of Set 10 | middlebury
# Processing Record 26 of Set 10 | saint anthony
# Processing Record 27 of Set 10 | sibolga
# Processing Record 28 of Set 10 | lata
# Processing Record 29 of Set 10 | port hedland
# Processing Record 30 of Set 10 | veraval
# Processing Record 31 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | ampanihy
# Processing Record 34 of Set 10 | neuquen
# Processing Record 35 of Set 10 | sao felix do xingu
# Processing Record 36 of Set 10 | nyurba
# Processing Record 37 of Set 10 | newark
# Processing Record 38 of Set 10 | fernley
# Processing Record 39 of Set 10 | alexandria
# Processing Record 40 of Set 10 | inhambane
# Processing Record 41 of Set 10 | liusha
# Processing Record 42 of Set 10 | birao
# Processing Record 43 of Set 10 | brownsville
# Processing Record 44 of Set 10 | lac du bonnet
# Processing Record 45 of Set 10 | faya
# Processing Record 46 of Set 10 | cozumel
# Processing Record 47 of Set 10 | natal
# Processing Record 48 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 10 | vestmanna
# Processing Record 50 of Set 10 | durusu
# Processing Record 1 of Set 11 | warren
# Processing Record 2 of Set 11 | oksfjord
# Processing Record 3 of Set 11 | vao
# Processing Record 4 of Set 11 | ahuimanu
# Processing Record 5 of Set 11 | parry sound
# Processing Record 6 of Set 11 | chernyshevskiy
# Processing Record 7 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 11 | constitucion
# Processing Record 9 of Set 11 | springdale
# Processing Record 10 of Set 11 | gerash
# Processing Record 11 of Set 11 | bardiyah
# Processing Record 12 of Set 11 | obo
# Processing Record 13 of Set 11 | zaraza
# Processing Record 14 of Set 11 | rosario
# Processing Record 15 of Set 11 | pithora
# Processing Record 16 of Set 11 | saldanha
# Processing Record 17 of Set 11 | vagay
# Processing Record 18 of Set 11 | weihe
# Processing Record 19 of Set 11 | gryazovets
# Processing Record 20 of Set 11 | sheridan
# Processing Record 21 of Set 11 | okmulgee
# Processing Record 22 of Set 11 | tornio
# Processing Record 23 of Set 11 | sullana
# Processing Record 24 of Set 11 | sambava
# Processing Record 25 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 11 | gryfino
# Processing Record 27 of Set 11 | bahraich
# Processing Record 28 of Set 11 | chateau-thierry
# Processing Record 29 of Set 11 | anadyr
# Processing Record 30 of Set 11 | broome
# Processing Record 31 of Set 11 | mawlaik
# Processing Record 32 of Set 11 | puerto montt
# Processing Record 33 of Set 11 | katangli
# Processing Record 34 of Set 11 | zhigansk
# Processing Record 35 of Set 11 | weymouth
# Processing Record 36 of Set 11 | port augusta
# Processing Record 37 of Set 11 | namibe
# Processing Record 38 of Set 11 | hov
# Processing Record 39 of Set 11 | san quintin
# Processing Record 40 of Set 11 | auki
# Processing Record 41 of Set 11 | nacogdoches
# Processing Record 42 of Set 11 | boa vista
# Processing Record 43 of Set 11 | jais
# Processing Record 44 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 11 | kattivakkam
# Processing Record 46 of Set 11 | fort nelson
# Processing Record 47 of Set 11 | mitu
# Processing Record 48 of Set 11 | warrington
# Processing Record 49 of Set 11 | los llanos de aridane
# Processing Record 50 of Set 11 | pacific grove
# Processing Record 1 of Set 12 | antofagasta
# Processing Record 2 of Set 12 | mabaruma
# Processing Record 3 of Set 12 | petropavlovka
# Processing Record 4 of Set 12 | barcelos
# Processing Record 5 of Set 12 | huarmey
# Processing Record 6 of Set 12 | narwar
# Processing Record 7 of Set 12 | kirksville
# Processing Record 8 of Set 12 | koumac
# Processing Record 9 of Set 12 | wagar
# Processing Record 10 of Set 12 | sulina
# Processing Record 11 of Set 12 | ramanuj ganj
# Processing Record 12 of Set 12 | naze
# Processing Record 13 of Set 12 | weinan
# Processing Record 14 of Set 12 | ontario
# Processing Record 15 of Set 12 | burgos
# Processing Record 16 of Set 12 | lufilufi
# Processing Record 17 of Set 12 | chegdomyn
# Processing Record 18 of Set 12 | evensk
# Processing Record 19 of Set 12 | jinxiang
# Processing Record 20 of Set 12 | dingle
# Processing Record 21 of Set 12 | fairbanks
# Processing Record 22 of Set 12 | raudeberg
# Processing Record 23 of Set 12 | preobrazheniye
# Processing Record 24 of Set 12 | itoman
# Processing Record 25 of Set 12 | whitehorse
# Processing Record 26 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 12 | coxim
# Processing Record 28 of Set 12 | buchanan
# Processing Record 29 of Set 12 | atasu
# Processing Record 30 of Set 12 | talnakh
# Processing Record 31 of Set 12 | nouadhibou
# Processing Record 32 of Set 12 | blind river
# Processing Record 33 of Set 12 | acapulco
# Processing Record 34 of Set 12 | nemuro
# Processing Record 35 of Set 12 | saint-louis
# Processing Record 36 of Set 12 | zeven
# Processing Record 37 of Set 12 | semey
# Processing Record 38 of Set 12 | andenes
# Processing Record 39 of Set 12 | funadhoo
# Processing Record 40 of Set 12 | burnie
# Processing Record 41 of Set 12 | muros
# Processing Record 42 of Set 12 | wanxian
# Processing Record 43 of Set 12 | tres lagoas
# Processing Record 44 of Set 12 | saint-francois
# Processing Record 45 of Set 12 | yeppoon
# Processing Record 46 of Set 12 | pangnirtung
# Processing Record 47 of Set 12 | dzhebariki-khaya
# Processing Record 48 of Set 12 | kutum
# Processing Record 49 of Set 12 | sai buri
# Processing Record 50 of Set 12 | dunedin
# Processing Record 1 of Set 13 | kibaya
# Processing Record 2 of Set 13 | piacabucu
# Processing Record 3 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 13 | bengkulu
# Processing Record 5 of Set 13 | poya
# Processing Record 6 of Set 13 | fukue
# Processing Record 7 of Set 13 | flinders
# Processing Record 8 of Set 13 | mporokoso
# Processing Record 9 of Set 13 | qaqortoq
# Processing Record 10 of Set 13 | sandviken
# Processing Record 11 of Set 13 | northam
# Processing Record 12 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 13 | gijon
# Processing Record 14 of Set 13 | mogadishu
# Processing Record 15 of Set 13 | manokwari
# Processing Record 16 of Set 13 | ubinskoye
# Processing Record 17 of Set 13 | palmer
# Processing Record 18 of Set 13 | pingliang
# Processing Record 19 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 13 | hami
# Processing Record 21 of Set 13 | arkadak
# Processing Record 22 of Set 13 | pauini
# Processing Record 23 of Set 13 | hervey bay
# Processing Record 24 of Set 13 | mbala
# Processing Record 25 of Set 13 | benxi
# Processing Record 26 of Set 13 | assisi
# Processing Record 27 of Set 13 | weihai
# Processing Record 28 of Set 13 | skibbereen
# Processing Record 29 of Set 13 | labuhan
# Processing Record 30 of Set 13 | ningxiang
# Processing Record 31 of Set 13 | tateyama
# Processing Record 32 of Set 13 | tevaitoa
# Processing Record 33 of Set 13 | medea
# Processing Record 34 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 35 of Set 13 | ambon
# Processing Record 36 of Set 13 | lawrenceburg
# Processing Record 37 of Set 13 | srednekolymsk
# Processing Record 38 of Set 13 | namatanai
# Processing Record 39 of Set 13 | victoria
# Processing Record 40 of Set 13 | seymour
# Processing Record 41 of Set 13 | skegness
# Processing Record 42 of Set 13 | gorom-gorom
# Processing Record 43 of Set 13 | chandbali
# Processing Record 44 of Set 13 | hit
# Processing Record 45 of Set 13 | puerto carreno
# Processing Record 46 of Set 13 | korla
# Processing Record 47 of Set 13 | yangliuqing
# Processing Record 48 of Set 13 | elizabeth city
# Processing Record 49 of Set 13 | zalantun
# Processing Record 50 of Set 13 | aras
# Processing Record 1 of Set 14 | yefimovskiy
# City not found. Skipping...
# Processing Record 2 of Set 14 | taian
# Processing Record 3 of Set 14 | fort-shevchenko
# Processing Record 4 of Set 14 | filingue
# Processing Record 5 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 14 | liverpool
# Processing Record 7 of Set 14 | rawson
# Processing Record 8 of Set 14 | surskoye
# Processing Record 9 of Set 14 | caravelas
# Processing Record 10 of Set 14 | mar del plata
# Processing Record 11 of Set 14 | west wendover
# Processing Record 12 of Set 14 | liuzhou
# Processing Record 13 of Set 14 | akyab
# Processing Record 14 of Set 14 | severnyy
# Processing Record 15 of Set 14 | xinzhi
# Processing Record 16 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 14 | tautira
# Processing Record 18 of Set 14 | sa kaeo
# Processing Record 19 of Set 14 | oxbow
# Processing Record 20 of Set 14 | lokosovo
# Processing Record 21 of Set 14 | puerto palomas
# Processing Record 22 of Set 14 | beauceville
# Processing Record 23 of Set 14 | szczytno
# Processing Record 24 of Set 14 | komsomolskiy
# Processing Record 25 of Set 14 | asfi
# Processing Record 26 of Set 14 | eirunepe
# Processing Record 27 of Set 14 | oktyabrskiy
# Processing Record 28 of Set 14 | tiruchchendur
# Processing Record 29 of Set 14 | chimbote
# Processing Record 30 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 14 | riverton
# Processing Record 32 of Set 14 | batagay-alyta
# Processing Record 33 of Set 14 | rio claro
# Processing Record 34 of Set 14 | kamaishi
# Processing Record 35 of Set 14 | kuminskiy
# Processing Record 36 of Set 14 | kuchinarai
# Processing Record 37 of Set 14 | fayaoue
# Processing Record 38 of Set 14 | the valley
# Processing Record 39 of Set 14 | samoded
# Processing Record 40 of Set 14 | eureka
# Processing Record 41 of Set 14 | vila franca do campo
# Processing Record 42 of Set 14 | bell ville
# Processing Record 43 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 14 | senmonorom
# City not found. Skipping...
# Processing Record 45 of Set 14 | ormond beach
# Processing Record 46 of Set 14 | kiruna
# Processing Record 47 of Set 14 | yulara
# Processing Record 48 of Set 14 | chicama
# Processing Record 49 of Set 14 | sisimiut
# Processing Record 50 of Set 14 | ati
# Processing Record 1 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 15 | san-pedro
# Processing Record 3 of Set 15 | cairns
# Processing Record 4 of Set 15 | arman
# Processing Record 5 of Set 15 | yabrud
# Processing Record 6 of Set 15 | parfenyevo
# Processing Record 7 of Set 15 | khuzdar
# Processing Record 8 of Set 15 | matagami
# Processing Record 9 of Set 15 | el dorado
# Processing Record 10 of Set 15 | la libertad
# Processing Record 11 of Set 15 | niny
# Processing Record 12 of Set 15 | ishigaki
# Processing Record 13 of Set 15 | praia da vitoria
# Processing Record 14 of Set 15 | japura
# Processing Record 15 of Set 15 | sinazongwe
# Processing Record 16 of Set 15 | tuensang
# Processing Record 17 of Set 15 | kungurtug
# Processing Record 18 of Set 15 | blackwater
# Processing Record 19 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 15 | monte azul
# Processing Record 21 of Set 15 | gayeri
# Processing Record 22 of Set 15 | racale
# Processing Record 23 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 24 of Set 15 | meadow lake
# Processing Record 25 of Set 15 | atbasar
# Processing Record 26 of Set 15 | leinefelde
# Processing Record 27 of Set 15 | alto araguaia
# Processing Record 28 of Set 15 | gillette
# Processing Record 29 of Set 15 | tucuman
# Processing Record 30 of Set 15 | pangody
# Processing Record 31 of Set 15 | roald
# Processing Record 32 of Set 15 | loviisa
# Processing Record 33 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 15 | salalah
# Processing Record 35 of Set 15 | coquimbo
# Processing Record 36 of Set 15 | nandgaon
# Processing Record 37 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 38 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 15 | camacha
# Processing Record 40 of Set 15 | gornyy
# Processing Record 41 of Set 15 | kuah
# Processing Record 42 of Set 15 | kosa
# Processing Record 43 of Set 15 | nuuk
# Processing Record 44 of Set 15 | tuy hoa
# Processing Record 45 of Set 15 | kalmunai
# Processing Record 46 of Set 15 | alice town
# Processing Record 47 of Set 15 | kurilsk
# Processing Record 48 of Set 15 | lethem
# Processing Record 49 of Set 15 | bekhtery
# Processing Record 50 of Set 15 | sari
# Processing Record 1 of Set 16 | novoseleznevo
# Processing Record 2 of Set 16 | svetlaya
# Processing Record 3 of Set 16 | grootfontein
# Processing Record 4 of Set 16 | dehloran
# Processing Record 5 of Set 16 | ixtapa
# Processing Record 6 of Set 16 | kulhudhuffushi
# Processing Record 7 of Set 16 | morti
# City not found. Skipping...
# Processing Record 8 of Set 16 | kushiro
# Processing Record 9 of Set 16 | muzhi
# Processing Record 10 of Set 16 | pershotravneve
# Processing Record 11 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 16 | kilkenny
# Processing Record 13 of Set 16 | pecos
# Processing Record 14 of Set 16 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 16 | mgandu
# Processing Record 16 of Set 16 | pouembout
# Processing Record 17 of Set 16 | padang
# Processing Record 18 of Set 16 | salinas
# Processing Record 19 of Set 16 | bubaque
# Processing Record 20 of Set 16 | axim
# Processing Record 21 of Set 16 | haverfordwest
# Processing Record 22 of Set 16 | vratnica
# Processing Record 23 of Set 16 | vazhiny
# Processing Record 24 of Set 16 | ulladulla
# Processing Record 25 of Set 16 | egvekinot
# Processing Record 26 of Set 16 | jawhar
# Processing Record 27 of Set 16 | denau
# City not found. Skipping...
# Processing Record 28 of Set 16 | la seyne-sur-mer
# Processing Record 29 of Set 16 | paradwip
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0        Waingapu  -9.6567  120.2641     overcast clouds     79.74        81
# 1        Khatanga  71.9667  102.5000     overcast clouds     -7.24        92
# 2           Pisco -13.7000  -76.2167           clear sky     69.85        73
# 3         Ushuaia -54.8000  -68.3000           clear sky     53.26        35
# 4          Hobart -42.8794  147.3294           clear sky     58.86        67
# 5         Rikitea -23.1203 -134.9692          light rain     75.79        79
# 6           Tiksi  71.6872  128.8694     overcast clouds     -5.71        97
# 7  Port Elizabeth -33.9180   25.5701           clear sky     61.09        77
# 8          Bethel  41.3712  -73.4140           clear sky     37.76        38
# 9            Nome  64.5011 -165.4064           clear sky     -5.73        59
#
#    Cloudiness  Wind Speed Country
# 0          99        5.08      ID
# 1         100       14.23      RU
# 2           0       18.41      PE
# 3           0       10.36      AR
# 4           0       10.36      AU
# 5          11       15.21      PF
# 6         100        7.00      RU
# 7           0        5.75      ZA
# 8           1        9.22      US
# 9           1       10.36      US

# %%
city_data_df_reordered = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_df_reordered]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Waingapu      ID  -9.6567  120.2641     79.74        81          99
# 1        Khatanga      RU  71.9667  102.5000     -7.24        92         100
# 2           Pisco      PE -13.7000  -76.2167     69.85        73           0
# 3         Ushuaia      AR -54.8000  -68.3000     53.26        35           0
# 4          Hobart      AU -42.8794  147.3294     58.86        67           0
# 5         Rikitea      PF -23.1203 -134.9692     75.79        79          11
# 6           Tiksi      RU  71.6872  128.8694     -5.71        97         100
# 7  Port Elizabeth      ZA -33.9180   25.5701     61.09        77           0
# 8          Bethel      US  41.3712  -73.4140     37.76        38           1
# 9            Nome      US  64.5011 -165.4064     -5.73        59           1
#
#    Wind Speed Current Description
# 0        5.08     overcast clouds
# 1       14.23     overcast clouds
# 2       18.41           clear sky
# 3       10.36           clear sky
# 4       10.36           clear sky
# 5       15.21          light rain
# 6        7.00     overcast clouds
# 7        5.75           clear sky
# 8        9.22           clear sky
# 9       10.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
